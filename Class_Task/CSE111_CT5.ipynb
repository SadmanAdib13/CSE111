# %% [markdown]
# <a href="https://colab.research.google.com/github/SadmanAdib13/CSE111/blob/main/Class_Task/CSE111_CT5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1
class Student:
    def __init__(self, name, student_id, program='CSE'):
        self.name = name
        self.student_id = student_id
        self.program = program

    def dailyEffort(self, hours):
        self.daily_effort = hours

    def printDetails(self):
        print(f"Name: {self.name}")
        print(f"Student ID: {self.student_id}")
        print(f"Program: {self.program}")
        print(f"Daily Effort: {self.daily_effort} hours")

        if self.daily_effort<=4:
            print("Suggestion: Keep up the good work!")
        elif self.daily_effort<=2:
            print("Suggestion: Should give more effort!")
        else:
            print("Suggestion: Excellent! Now motivate others.")

# Creating instances of the Student class
harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')

john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')

naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# Student ID: 123
# Program: CSE
# Daily Effort: 3 hours
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# Student ID: 456
# Program: BBA
# Daily Effort: 2 hours
# Suggestion: Keep up the good work!
# ...
# Name: Naruto Uzumaki
# Student ID: 777
# Program: Ninja
# Daily Effort: 6 hours
# Suggestion: Excellent! Now motivate others.

# %%
#Task 2


class Farmer:
  def __init__(self,name=None,val=None):

    self.farmer_name=val
    self.farmer_id=val
    self.crops=[]
    self.fishes=[]
    if self.farmer_name:
        print(f"Welcome to your farm, {self.farmer_name}!")
    elif self.farmer_id:
        print(f"Welcome to your farm. Your farm ID is {self.farm_id}!")
    else:
      print('Welcome to your farm! ')



  def addCrops(self, *crops):
        if crops:
            self.crops.extend(crops)
            print(f"{len(crops)} crop(s) added.")
        else:
            print("No crop(s) added.")

  def addFishes(self, *fishes):
        if fishes:
            self.fishes.extend(fishes)
            print(f"{len(fishes)} fish(s) added.")
        else:
            print("No fish added.")

  def showGoods(self):
        if self.crops:
            print(f"You have {len(self.crops)} crop(s): {','.join(self.crops)}")
        else:
            print("You don't have any crop(s).")

        if self.fishes:
            print(f"You have {len(self.fishes)} fish(s): {','.join(self.fishes)}")
        else:
            print("You don't have any fish(s).")
        print("-------------------")


f1 = Farmer()
print("-------------------")
f1.addCrops('Rice', "Jute", "Cinnamon")
print("-------------------")
f1.addFishes()
print("-------------------")
f1.addCrops('Mustard')
print("-------------------")
f1.showGoods()
print("-------------------")
f2 = Farmer("Korim Mia")
print("-------------------")
f2.addFishes('Pangash', 'Magur')
print("-------------------")
f2.addCrops("Wheat", "Potato")
print("-------------------")
f2.addFishes("Koi", "Tuna", "Sardine")
print("-------------------")
f2.showGoods()
print("-------------------")
f3 = Farmer(2865127000)
print("-------------------")
f3.addCrops()
print("-------------------")
f3.addFishes("Katla")
print("-------------------")
f3.showGoods()
print("-------------------")
# Out:
# Welcome to your farm!
# -------------------
# 3 crop(s) added.
# -------------------
# No fish added.
# -------------------
# 1 crop(s) added.
# -------------------
# You have 4 crop(s): Rice,Jute,Cinnamon,Mustard
# You don't have any fish(s).
# -------------------
# -------------------
# Welcome to your farm!
# -------------------
# 2 fish(s) added.
# -------------------
# 2 crop(s) added.
# -------------------
# 3 fish(s) added.
# -------------------
# You have 2 crop(s): Wheat,Potato
# You have 5 fish(s): Pangash,Magur,Koi,Tuna,Sardine
# -------------------
# -------------------
# Welcome to your farm!
# -------------------
# No crop(s) added.
# -------------------
# 1 fish(s) added.
# -------------------
# You don't have any crop(s).
# You have 1 fish(s): Katla
# -------------------
# -------------------

# %%
class TaxiLagbe:
    def __init__(self, taxi_number, area):
        self.taxi_number = taxi_number
        self.area = area
        self.passengers = []
        self.total_exp = 0


    def addPassenger(self, *passengers):
        for i in passengers:
            passenger, cost = i.split('_')
            #print(passenger,cost)
            self.passengers.append(passenger)
            if len(self.passengers) > 4:
                print("Taxi Full! No more passengers can be added.")
                break

            else:
             print(f"Dear {passenger}! Welcome to TaxiLagbe.")


             self.total_exp += int(cost)



    def printDetails(self):
        print(f"\nTrip info for Taxi number: {self.taxi_number}")
        print(f"This taxi can only cover the {self.area} area.")
        print(f"Total passengers: {len(self.passengers)}")
        print("Passenger lists:")
        print(', '.join(self.passengers))
        print(f"Total collected fare: {self.total_exp} Taka")

# Driver code
taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200', 'Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115', 'Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Walker 100
# Dear Walker! Welcome to TaxiLagbe.
# Wood 200
# Dear Wood! Welcome to TaxiLagbe.
# Matt 100
# Dear Matt! Welcome to TaxiLagbe.
# Wilson 105
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
#
# Trip info for Taxi number: 1010-01
# This taxi can only cover the Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# -------------------------------
# Karen 200
# Taxi Full! No more passengers can be added.
# -------------------------------
#
# Trip info for Taxi number: 1010-01
# This taxi can only cover the Dhaka area.
# Total passengers: 5
# Passenger lists:
# Walker, Wood, Matt, Wilson, Karen
# Total collected fare: 505 Taka
# -------------------------------
# Ronald 115
# Dear Ronald! Welcome to TaxiLagbe.
# Parker 215
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
#
# Trip info for Taxi number: 1010-02
# ...

# %%
#Task 5
class Sphere:
  def __init__(self,name,radious='1',color='white'):
    self.name=name
    self.radious=radious
    self.color=color
  def printDetails(self):
    print(f'Sphere ID:{self.name}\n color:{self.color} \n volume:{self.color}')
  def merge_sphere(self)
sphere1 = Sphere("Sphere 1")
print("1***************")
sphere1.printDetails()
print("2***************")
sphere2 = Sphere("Sphere 2", 3)
print("3***************")
sphere2.printDetails()
print("4***************")
sphere3 = Sphere("Sphere 3", 2)
print("5***************")
sphere3.printDetails()
print("6***************")
sphere3.merge_sphere(sphere1,sphere2)
print("7***************")
sphere3.printDetails()
print("8***************")
sphere4 = Sphere("Sphere 4", 5, "Purple")
print("9***************")
sphere4.merge_sphere(sphere3)
# Out:
# 1***************
# Sphere ID:Sphere 1/n color:white /n volume:white
# 2***************
# 3***************
# Sphere ID:Sphere 2/n color:white /n volume:white
# 4***************
# 5***************
# Sphere ID:Sphere 3/n color:white /n volume:white
# 6***************
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e17c53f0595a> in <cell line: 22>()
#      20 sphere3.printDetails()
#      21 print("6***************")
# ---> 22 sphere3.merge_sphere(sphere1,sphere2)
#      23 print("7***************")
#      24 sphere3.printDetails()
#
# AttributeError: 'Sphere' object has no attribute 'merge_sphere'

# %%
from PIL import Image, ImageDraw

# Create a new image with a white background
width, height = 300, 200
image = Image.new("RGB", (width, height), "white")

# Create a drawing object
draw = ImageDraw.Draw(image)

# Draw a red rectangle on the image
rectangle_color = "red"
rectangle_coordinates = [(50, 50), (250, 150)]
draw.rectangle(rectangle_coordinates, fill=rectangle_color)

# Save the image to a file
image.save("example_image.png")

# Display the image
image.show()
